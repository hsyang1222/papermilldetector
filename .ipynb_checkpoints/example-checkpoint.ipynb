# %%
import template_match as tm

# %%
#처음 한번 western blot의 template를 가져옴

template_dir = '../split_imageset/western_img/'
template_filenamelist, template_img = tm.template_load(template_dir)
# Out:
# 100%|██████████| 2318/2318 [00:00<00:00, 6086.68it/s]

# %%
#논문 pdf를 입력하면 이미지로 추출
pdf_file_dir = '../paper/10.pdf'
only_paper_name = get_original_paper_name(pdf_file_dir)
image_list = tm.pdf_to_img(pdf_file_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-55257efab7af> in <module>
#       1 #논문 pdf를 입력하면 이미지로 추출
#       2 pdf_file_dir = '../paper/10.pdf'
# ----> 3 only_paper_name = get_original_paper_name(pdf_file_dir)
#       4 image_list = tm.pdf_to_img(pdf_file_dir)
#
# NameError: name 'get_original_paper_name' is not defined

# %%
select_paper_img = image_list[1]

# %%
matching_result = tm.match_image_with_template(template_filenamelist, template_img, select_paper_img, N=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e326930860fc> in <module>
# ----> 1 matching_result = tm.match_image_with_template(template_filenamelist, template_img, select_paper_img, N=5)
#
# NameError: name 'select_paper_img' is not defined

# %%
matching_result[3]
